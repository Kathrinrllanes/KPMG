# %%
import datetime as dt
from arcgis.gis import GIS
import arcgis.geometry as geometry
import arcgis.network as network
import arcgis.features as features

# %%
user_name = "kllanes"
password = "mipass_2018"

my_gis = GIS("https://www.arcgis.com", user_name, password)

# %%
stops = {'features': [{'attributes': {'CurbApproach': 1,
    'Name': '138',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 445841, 'y': 4471895}},
  {'attributes': {'CurbApproach': 1,
    'Name': '137',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 445874, 'y': 4471940}},
  {'attributes': {'CurbApproach': 1,
    'Name': '136',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 445569, 'y': 4471929}},
  {'attributes': {'CurbApproach': 1,
    'Name': '131',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 445168, 'y': 4472241}},
  {'attributes': {'CurbApproach': 1,
    'Name': '384',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444726, 'y': 4472958}},
  {'attributes': {'CurbApproach': 1,
    'Name': '4',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444631, 'y': 4472995}},
  {'attributes': {'CurbApproach': 1,
    'Name': '3',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444552, 'y': 4473012}},
  {'attributes': {'CurbApproach': 1,
    'Name': '27',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444495, 'y': 4473030}},
  {'attributes': {'CurbApproach': 1,
    'Name': '26',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444453, 'y': 4473044}},
  {'attributes': {'CurbApproach': 1,
    'Name': '21',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444348, 'y': 4473089}},
  {'attributes': {'CurbApproach': 1,
    'Name': '20',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444280, 'y': 4473112}},
  {'attributes': {'CurbApproach': 1,
    'Name': '381',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444174, 'y': 4473155}},
  {'attributes': {'CurbApproach': 1,
    'Name': '126',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444094, 'y': 4473269}},
  {'attributes': {'CurbApproach': 1,
    'Name': '74',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444203, 'y': 4473289}},
  {'attributes': {'CurbApproach': 1,
    'Name': '231',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444285, 'y': 4473336}},
  {'attributes': {'CurbApproach': 1,
    'Name': '72',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444281, 'y': 4473430}},
  {'attributes': {'CurbApproach': 1,
    'Name': '198',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444367, 'y': 4473468}},
  {'attributes': {'CurbApproach': 1,
    'Name': '197',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444467, 'y': 4473437}},
  {'attributes': {'CurbApproach': 1,
    'Name': '199',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444532, 'y': 4473385}},
  {'attributes': {'CurbApproach': 1,
    'Name': '53',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444578, 'y': 4473345}},
  {'attributes': {'CurbApproach': 1,
    'Name': '52',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444616, 'y': 4473422}},
  {'attributes': {'CurbApproach': 1,
    'Name': '193',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444658, 'y': 4473582}},
  {'attributes': {'CurbApproach': 1,
    'Name': '46',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444597, 'y': 4473712}},
  {'attributes': {'CurbApproach': 1,
    'Name': '80',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444552, 'y': 4473814}},
  {'attributes': {'CurbApproach': 1,
    'Name': '77',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444482, 'y': 4473826}},
  {'attributes': {'CurbApproach': 1,
    'Name': '76',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444426, 'y': 4473824}},
  {'attributes': {'CurbApproach': 1,
    'Name': '45',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444472, 'y': 4473752}},
  {'attributes': {'CurbApproach': 1,
    'Name': '81',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444492, 'y': 4473690}},
  {'attributes': {'CurbApproach': 1,
    'Name': '79',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444468, 'y': 4473657}},
  {'attributes': {'CurbApproach': 1,
    'Name': '78',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444438, 'y': 4473613}},
  {'attributes': {'CurbApproach': 1,
    'Name': '75',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444444, 'y': 4473644}},
  {'attributes': {'CurbApproach': 1,
    'Name': '124',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444324, 'y': 4473703}},
  {'attributes': {'CurbApproach': 1,
    'Name': '51',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444247, 'y': 4473709}},
  {'attributes': {'CurbApproach': 1,
    'Name': '63',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444254, 'y': 4473640}},
  {'attributes': {'CurbApproach': 1,
    'Name': '372',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444392, 'y': 4473640}},
  {'attributes': {'CurbApproach': 1,
    'Name': '239',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444186, 'y': 4473947}},
  {'attributes': {'CurbApproach': 1,
    'Name': '237',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444081, 'y': 4473981}},
  {'attributes': {'CurbApproach': 1,
    'Name': '247',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444059, 'y': 4474052}},
  {'attributes': {'CurbApproach': 1,
    'Name': '236',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444090, 'y': 4474117}},
  {'attributes': {'CurbApproach': 1,
    'Name': '238',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444166, 'y': 4474181}},
  {'attributes': {'CurbApproach': 1,
    'Name': '244',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444218, 'y': 4474152}},
  {'attributes': {'CurbApproach': 1,
    'Name': '246',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444205, 'y': 4474144}},
  {'attributes': {'CurbApproach': 1,
    'Name': '243',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444223, 'y': 4474110}},
  {'attributes': {'CurbApproach': 1,
    'Name': '245',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444209, 'y': 4474102}},
  {'attributes': {'CurbApproach': 1,
    'Name': '242',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444215, 'y': 4474072}},
  {'attributes': {'CurbApproach': 1,
    'Name': '240',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444212, 'y': 4474050}},
  {'attributes': {'CurbApproach': 1,
    'Name': '248',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444195, 'y': 4474035}},
  {'attributes': {'CurbApproach': 1,
    'Name': '241',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444189, 'y': 4473992}},
  {'attributes': {'CurbApproach': 1,
    'Name': '60',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444244, 'y': 4473954}},
  {'attributes': {'CurbApproach': 1,
    'Name': '61',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444276, 'y': 4473968}},
  {'attributes': {'CurbApproach': 1,
    'Name': '59',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444490, 'y': 4473857}},
  {'attributes': {'CurbApproach': 1,
    'Name': '58',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444425, 'y': 4473880}},
  {'attributes': {'CurbApproach': 1,
    'Name': '209',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444112, 'y': 4473844}},
  {'attributes': {'CurbApproach': 1,
    'Name': '206',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444084, 'y': 4473865}},
  {'attributes': {'CurbApproach': 1,
    'Name': '205',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444058, 'y': 4473876}},
  {'attributes': {'CurbApproach': 1,
    'Name': '204',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444019, 'y': 4473873}},
  {'attributes': {'CurbApproach': 1,
    'Name': '203',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444010, 'y': 4473844}},
  {'attributes': {'CurbApproach': 1,
    'Name': '202',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444028, 'y': 4473822}},
  {'attributes': {'CurbApproach': 1,
    'Name': '201',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444056, 'y': 4473812}},
  {'attributes': {'CurbApproach': 1,
    'Name': '208',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444183, 'y': 4473818}},
  {'attributes': {'CurbApproach': 1,
    'Name': '207',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444180, 'y': 4473776}},
  {'attributes': {'CurbApproach': 1,
    'Name': '200',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444158, 'y': 4473706}},
  {'attributes': {'CurbApproach': 1,
    'Name': '57',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444135, 'y': 4473486}},
  {'attributes': {'CurbApproach': 1,
    'Name': '56',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444013, 'y': 4473410}},
  {'attributes': {'CurbApproach': 1,
    'Name': '406',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 443894, 'y': 4473402}},
  {'attributes': {'CurbApproach': 1,
    'Name': '404',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 443787, 'y': 4473419}},
  {'attributes': {'CurbApproach': 1,
    'Name': '405',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 443803, 'y': 4473507}},
  {'attributes': {'CurbApproach': 1,
    'Name': '50',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 443906, 'y': 4473327}},
  {'attributes': {'CurbApproach': 1,
    'Name': '55',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 443851, 'y': 4473288}},
  {'attributes': {'CurbApproach': 1,
    'Name': '125',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 443944, 'y': 4473228}},
  {'attributes': {'CurbApproach': 1,
    'Name': '127',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 443961, 'y': 4473273}},
  {'attributes': {'CurbApproach': 1,
    'Name': '17',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 443952, 'y': 4473199}},
  {'attributes': {'CurbApproach': 1,
    'Name': '18',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444039, 'y': 4473170}},
  {'attributes': {'CurbApproach': 1,
    'Name': '386',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444615, 'y': 4472973}},
  {'attributes': {'CurbApproach': 1,
    'Name': '54',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 444734, 'y': 4472837}},
  {'attributes': {'CurbApproach': 1,
    'Name': '133',
    'PickupQuantities': 1,
    'ServiceTime': 60},
   'geometry': {'x': 445358, 'y': 4472131}}],
 'fields': [{'alias': 'Name',
   'length': '50',
   'name': 'Name',
   'type': 'esriFieldTypeString'},
  {'alias': 'CurbApproach',
   'name': 'CurbApproach',
   'type': 'esriFieldTypeInteger'},
  {'alias': 'PickupQuantities',
   'name': 'PickupQuantities',
   'type': 'esriFieldTypeInteger'},
  {'alias': 'ServiceTime',
   'name': 'ServiceTime',
   'type': 'esriFieldTypeInteger'}],
 'geometryType': 'esriGeometryPoint',
 'spatialReference': {'latestWkid': 25830, 'wkid': 25830}}

# %%
#depot1
Mercadona_X = 446882   
Mercadona_Y = 4470463

#depot2
Repsol_X = 450053
Repsol_Y = 4466340

depots = features.FeatureSet.from_dict({
    "features": [{"attributes": {"Name": "Depot1"},
                  "geometry": {"x": Mercadona_X, "y": Mercadona_Y}},
                 
                 {"attributes": {"Name": "Depot2"}, 
                  "geometry": {"x": Repsol_X, "y": Repsol_Y}}],
    "spatialReference": {"wkid": 25830, "latestWkid": 25830},
    "geometryType": "esriGeometryPoint",
 "fields": [
        {"name" : "Name", "type" : "esriFieldTypeString", "alias" : "Name", "length" : "50"}
    ]
})

routes = features.FeatureSet.from_dict({ 
    "features": [{"attributes": {"Capacities": "30000 250000", 
                                 
                                 "EndDepotName": "Depot2",
                                 "Name": "Truck1",
                                 "MaxOrderCount" : 90, 
                                 "SpecialtyNames": "BucketTruck",
                                 "StartDepotName": "Depot1"}}
                ],
    "fields": [
        {"name" : "Name", "type" : "esriFieldTypeString", "alias" : "Name", "length" : "50"},
        {"name" : "Capacities", "type" : "esriFieldTypeString", "alias" : "Capacities", "length" : "50"},
        {"name" : "EndDepotName", "type" : "esriFieldTypeString", "alias" : "EndDepotName", "length" : "50"},
        {"name" : "StartDepotName", "type" : "esriFieldTypeString", "alias" : "StartDepotName", "length" : "50"},
        {"name" : "SpecialtyNames", "type" : "esriFieldTypeString", "alias" : "SpecialtyNames", "length" : "50"},
        {"name" : "MaxOrderCount", "type" : "esriFieldTypeInteger", "alias" : "MaxOrderCount"}
    ]
})

# %%
stops_r1 = features.FeatureSet.from_dict(stops)

# %%
stops_r1
# Out:
# <FeatureSet> 76 features

# %%
#está dando error!!!
VRP_result_r1 = network.analysis.solve_vehicle_routing_problem(orders=stops_r1, depots=depots, 
                                                        default_date=dt.datetime.now().date(), 
                                                        routes=routes, 
                                                        populate_route_lines=True,
                                                        #uturn_policy = 'NO_UTURNS',
                                                        uturn_policy = 'ALLOW_DEAD_ENDS_ONLY',
                                                        populate_directions=True,
                                                        directions_language="es")

# %%
VRP_result_r1
# Out:
# ToolOutput(out_unassigned_stops=<FeatureSet> 76 features, out_stops=<FeatureSet> 0 features, out_routes=<FeatureSet> 1 features, out_directions=<FeatureSet> 0 features, solve_succeeded=False)

# %%
#Partial Solution
VRP_result_r1_v1 = network.analysis.solve_vehicle_routing_problem(orders=stops_r1, depots=depots, 
                                                        default_date=dt.datetime.now().date(), 
                                                        routes=routes, 
                                                        populate_route_lines=True,
                                                        uturn_policy = 'NO_UTURNS',
                                                        #uturn_policy = 'ALLOW_DEAD_ENDS_ONLY',
                                                        populate_directions=True,
                                                        directions_language="es")
# Out:
# Some orders could not be routed due to violated constraints.
# WARNING 030025: Partial solution generated.

# %%
VRP_result_r1_v1
# Out:
# ToolOutput(out_unassigned_stops=<FeatureSet> 12 features, out_stops=<FeatureSet> 66 features, out_routes=<FeatureSet> 1 features, out_directions=<FeatureSet> 276 features, solve_succeeded=True)

# %%
import pandas as pd
import datetime
df_r1_v1 = VRP_result_r1_v1.out_directions.df
datetimes = pd.to_datetime(df_r1_v1["ArriveTime"] / 1000, unit="s")
df_r1_v1["ArriveTime"] = datetimes.apply(lambda x: x.strftime("%H:%M:%S"))
df_r1_v1[["ArriveTime", "DriveDistance", "ElapsedTime", "Text"]]
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/arcgis/features/_data/geodataset/geodataframe.py:1869: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   frame.set_value(index=idx, col=self._geometry_column_name, value=g)
#     ArriveTime  DriveDistance  ElapsedTime  \
# 0     08:00:00       0.000000     0.000000
# 1     08:00:00       0.775301     2.142815
# 2     08:02:08       0.730607     1.536581
# 3     08:03:40       0.452231     0.789033
# 4     08:04:28       0.054791     0.346392
# 5     08:04:48       0.021482     0.143908
# 6     08:04:57       0.039960     0.321506
# 7     08:05:16       0.000000    60.000000
# 8     09:05:16       0.000000     0.000000
# 9     09:05:16       0.042697     0.330985
# 10    09:05:36       0.080077     0.742564
# 11    09:06:21       0.065006     0.489123
# 12    09:06:50       0.034437     0.271523
# 13    09:07:06       0.092373     0.398795
# ...
